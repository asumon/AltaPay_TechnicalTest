# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Comma seperated csv file loading
df=pd.read_csv("altapay.20210201T000000+0000.csv",sep=';')

# %%
df.head(5)
# Out:
#   \total_sale_amount\               \total_fee_amount\ \total_return_amount\  \
# 0          \43969.95\                         \703.31\            \15287.49\
# 1              \type\                   \capture_date\          \capture_id\
# 2               \FEE\  \2020-01-01T12:26:46.000+00:00\        \11db360b111e\
# 3               \FEE\  \2021-01-02T05:48:03.000+00:00\        \a6691dd99235\
# 4               \FEE\  \2021-01-02T09:28:01.000+00:00\        \6c8be4e67217\
#
#   \total_settlement_amount\ \payment_reference\ \settlement_currency\  \
# 0                \27979.15\          \82242267\                 \EUR\
# 1                  \amount\  \posting_currency\           \refund_id\
# 2                    \4.03\               \EUR\                    \\
# 3                       \2\               \EUR\                    \\
# 4                    \4.45\               \EUR\                    \\
#
#                      \payout_date\ \merchant_id\ \merchant_settlement_type\
# ...

# %%
df.tail(5)
# Out:
#     \total_sale_amount\               \total_fee_amount\  \
# 653              \SALE\  \2021-01-10T05:39:32.000+00:00\
# 654              \SALE\  \2021-01-10T05:51:02.000+00:00\
# 655              \SALE\  \2021-01-10T16:54:59.000+00:00\
# 656              \SALE\  \2021-01-10T18:16:28.000+00:00\
# 657              \SALE\  \2021-01-10T20:06:55.000+00:00\
#
#     \total_return_amount\ \total_settlement_amount\ \payment_reference\  \
# 653        \a10d0e37d7c6\                   \311.9\               \EUR\
# 654        \2c38a7a841d4\                     \149\               \EUR\
# 655        \73b553bd2540\                     \179\               \EUR\
# 656        \68ee6ab91243\                  \131.95\               \EUR\
# 657        \4608df0e7df1\                   \127.9\               \EUR\
#
#     \settlement_currency\ \payout_date\ \merchant_id\  \
# 653                    \\    \PURCHASE\         \105\
# 654                    \\    \PURCHASE\         \105\
# ...

# %%
# Remove all unwanted slash
df = df.replace(to_replace= r'\\', value= '', regex=True)

# %%
# re-structure the data frame
header_row = 1 
df.columns = df.iloc[header_row]
df = df.drop(header_row) 
df = df.reset_index(drop=True)
df = df.drop(0)
df = df.reset_index(drop=True)

# %%
df.head(5)
# Out:
# 1 type                   capture_date    capture_id amount posting_currency  \
# 0  FEE  2020-01-01T12:26:46.000+00:00  11db360b111e   4.03              EUR
# 1  FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235      2              EUR
# 2  FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217   4.45              EUR
# 3  FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8   2.38              EUR
# 4  FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f   5.68              EUR
#
# 1 refund_id            detailed_type event_code  NaN
# 0            PURCHASE_FEE_PERCENTAGE        107  NaN
# 1            PURCHASE_FEE_PERCENTAGE        107  NaN
# 2            PURCHASE_FEE_PERCENTAGE        107  NaN
# 3            PURCHASE_FEE_PERCENTAGE        107  NaN
# 4            PURCHASE_FEE_PERCENTAGE        107  NaN

# %%
#Overview of dataframe and data structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              656 non-null    object
#  1   capture_date      656 non-null    object
#  2   capture_id        656 non-null    object
#  3   amount            656 non-null    object
#  4   posting_currency  656 non-null    object
#  5   refund_id         656 non-null    object
#  6   detailed_type     656 non-null    object
#  7   event_code        656 non-null    object
#  8   nan               0 non-null      object
# dtypes: object(9)
# memory usage: 46.2+ KB

# %%
# descriptive statistics
df.describe()
# Out:
# 1      type                   capture_date capture_id  amount  \
# count   656                            656        656     656
# unique    3                            464        281     260
# top     FEE  2021-01-18T10:25:38.000+00:00             159.95
# freq    280                              2         96      21
#
# 1      posting_currency refund_id            detailed_type event_code  NaN
# count               656       656                      656        656    0
# unique                1        97                        3          4    0
# top                 EUR            PURCHASE_FEE_PERCENTAGE        107  NaN
# freq                656       560                      280        280  NaN

# %%
# Object to Numaric conversion
df["event_code"] = pd.to_numeric(df["event_code"])

# %%
# Data Validation
indexNames = df[ (df['event_code'] == 105)]
indexNames
# Out:
# 1    type                   capture_date    capture_id  amount  \
# 376  SALE  2020-12-31T12:26:46.000+00:00  11db360b111e   251.9
# 377  SALE  2021-01-02T05:48:03.000+00:00  a6691dd99235  124.95
# 378  SALE  2021-01-02T09:28:01.000+00:00  6c8be4e67217   277.9
# 379  SALE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8     149
# 380  SALE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f  354.85
# ..    ...                            ...           ...     ...
# 650  SALE  2021-01-10T04:05:47.000+00:00  0ea2be93cd45   93.95
# 651  SALE  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 652  SALE  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 653  SALE  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 654  SALE  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
#
# 1   posting_currency refund_id detailed_type  event_code  NaN
# 376              EUR                PURCHASE         105  NaN
# 377              EUR                PURCHASE         105  NaN
# ...

# %%
# Data Validation
indexNames = df[ (df['event_code'] == 106)]
indexNames
# Out:
# 1      type                   capture_date capture_id  amount  \
# 280  RETURN  2021-01-05T10:14:50.000+00:00              94.95
# 281  RETURN  2021-01-05T14:45:12.000+00:00             131.95
# 282  RETURN  2021-01-06T10:15:40.000+00:00             119.95
# 283  RETURN  2021-01-06T10:16:27.000+00:00             106.95
# 284  RETURN  2021-01-07T10:09:53.000+00:00             138.95
# ..      ...                            ...        ...     ...
# 371  RETURN  2021-02-09T10:25:34.000+00:00              98.95
# 372  RETURN  2021-02-10T09:49:38.000+00:00             112.95
# 373  RETURN  2021-02-10T09:49:47.000+00:00             118.95
# 374  RETURN  2021-02-10T09:59:47.000+00:00              98.95
# 375  RETURN  2021-02-10T09:59:56.000+00:00                219
#
# 1   posting_currency     refund_id    detailed_type  event_code  NaN
# 280              EUR  b292036d5a7b  PURCHASE_RETURN         106  NaN
# 281              EUR  0b7d4bccebaa  PURCHASE_RETURN         106  NaN
# ...

# %%
# Data Validation
indexNames = df[ (df['event_code'] == 107)]
indexNames
# Out:
# 1   type                   capture_date    capture_id amount posting_currency  \
# 0    FEE  2020-01-01T12:26:46.000+00:00  11db360b111e   4.03              EUR
# 1    FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235      2              EUR
# 2    FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217   4.45              EUR
# 3    FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8   2.38              EUR
# 4    FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f   5.68              EUR
# ..   ...                            ...           ...    ...              ...
# 275  FEE  2021-02-10T05:39:32.000+00:00  a10d0e37d7c6   4.99              EUR
# 276  FEE  2021-02-10T05:51:02.000+00:00  2c38a7a841d4   2.38              EUR
# 277  FEE  2021-02-10T16:54:59.000+00:00  73b553bd2540   2.86              EUR
# 278  FEE  2021-02-10T18:16:28.000+00:00  68ee6ab91243   2.11              EUR
# 279  FEE  2021-02-10T20:06:55.000+00:00  4608df0e7df1   2.05              EUR
#
# ...

# %%
# Data Validation
indexNames = df[ (df['event_code'] == 107) | (df['event_code'] == 106) | (df['event_code'] == 105) ]
indexNames
# Out:
# 1    type                   capture_date    capture_id  amount  \
# 0     FEE  2020-01-01T12:26:46.000+00:00  11db360b111e    4.03
# 1     FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235       2
# 2     FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217    4.45
# 3     FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8    2.38
# 4     FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f    5.68
# ..    ...                            ...           ...     ...
# 650  SALE  2021-01-10T04:05:47.000+00:00  0ea2be93cd45   93.95
# 651  SALE  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 652  SALE  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 653  SALE  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 654  SALE  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
#
# 1   posting_currency refund_id            detailed_type  event_code  NaN
# 0                EUR            PURCHASE_FEE_PERCENTAGE         107  NaN
# ...
