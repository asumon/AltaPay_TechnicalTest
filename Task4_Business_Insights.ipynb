# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("82242267.20210201T000000+0000.csv",sep=';',header = None)
df
# Out:
#                        0                                1  \
# 0    \total_sale_amount\               \total_fee_amount\
# 1             \43969.95\                         \703.31\
# 2                 \type\                   \capture_date\
# 3                  \FEE\  \2020-01-01T12:26:46.000+00:00\
# 4                  \FEE\  \2021-01-02T05:48:03.000+00:00\
# ..                   ...                              ...
# 654               \SALE\  \2021-01-10T05:39:32.000+00:00\
# 655               \SALE\  \2021-01-10T05:51:02.000+00:00\
# 656               \SALE\  \2021-01-10T16:54:59.000+00:00\
# 657               \SALE\  \2021-01-10T18:16:28.000+00:00\
# 658               \SALE\  \2021-01-10T20:06:55.000+00:00\
#
#                          2                          3                    4  \
# 0    \total_return_amount\  \total_settlement_amount\  \payment_reference\
# 1               \15287.49\                 \27979.15\           \82242267\
# ...

# %%
#Delete all the '\'
df = df.replace(to_replace= r'\\', value= '', regex=True)

# %%
# Delete the 2nd row in the DataFrame (note indices starting from 0)
df = df.drop(td.index[[0,1]])
df
# Out:
#         0                              1             2       3  \
# 2    type                   capture_date    capture_id  amount
# 3     FEE  2020-01-01T12:26:46.000+00:00  11db360b111e    4.03
# 4     FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235       2
# 5     FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217    4.45
# 6     FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8    2.38
# ..    ...                            ...           ...     ...
# 654  SALE  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 655  SALE  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 656  SALE  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 657  SALE  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
# 658  SALE  2021-01-10T20:06:55.000+00:00  4608df0e7df1   127.9
#
#                     4          5                        6           7    8
# 2    posting_currency  refund_id            detailed_type  event_code  NaN
# ...

# %%
#make second row header in pandas
df.rename(columns=data.iloc[0])
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header

# %%
#Checking the dataframe
df.head(5)
# Out:
# 2 type                   capture_date    capture_id amount posting_currency  \
# 3  FEE  2020-01-01T12:26:46.000+00:00  11db360b111e   4.03              EUR
# 4  FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235      2              EUR
# 5  FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217   4.45              EUR
# 6  FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8   2.38              EUR
# 7  FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f   5.68              EUR
#
# 2 refund_id            detailed_type event_code  NaN
# 3            PURCHASE_FEE_PERCENTAGE        107  NaN
# 4            PURCHASE_FEE_PERCENTAGE        107  NaN
# 5            PURCHASE_FEE_PERCENTAGE        107  NaN
# 6            PURCHASE_FEE_PERCENTAGE        107  NaN
# 7            PURCHASE_FEE_PERCENTAGE        107  NaN

# %%
# descriptive statistics
df1.describe()

# %%
# Count total NaN at each column in a DataFrame
df.isnull().sum()
# Out:
# 2
# type                  0
# capture_date          0
# capture_id            0
# amount                0
# posting_currency      0
# refund_id             0
# detailed_type         0
# event_code            0
# NaN                 656
# dtype: int64

# %%
#Remove the column
del df["refund_id"]
df
# Out:
# 2    type                   capture_date    capture_id  amount  \
# 3     FEE  2020-01-01T12:26:46.000+00:00  11db360b111e    4.03
# 4     FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235       2
# 5     FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217    4.45
# 6     FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8    2.38
# 7     FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f    5.68
# ..    ...                            ...           ...     ...
# 654  SALE  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 655  SALE  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 656  SALE  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 657  SALE  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
# 658  SALE  2021-01-10T20:06:55.000+00:00  4608df0e7df1   127.9
#
# 2   posting_currency            detailed_type event_code  NaN
# 3                EUR  PURCHASE_FEE_PERCENTAGE        107  NaN
# 4                EUR  PURCHASE_FEE_PERCENTAGE        107  NaN
# ...

# %%
#Delete the column with 'NaN valur'
df1 = df.dropna(axis='columns')

# %%
df1
# Out:
# 2    type                   capture_date    capture_id  amount  \
# 3     FEE  2020-01-01T12:26:46.000+00:00  11db360b111e    4.03
# 4     FEE  2021-01-02T05:48:03.000+00:00  a6691dd99235       2
# 5     FEE  2021-01-02T09:28:01.000+00:00  6c8be4e67217    4.45
# 6     FEE  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8    2.38
# 7     FEE  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f    5.68
# ..    ...                            ...           ...     ...
# 654  SALE  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 655  SALE  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 656  SALE  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 657  SALE  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
# 658  SALE  2021-01-10T20:06:55.000+00:00  4608df0e7df1   127.9
#
# 2   posting_currency            detailed_type event_code
# 3                EUR  PURCHASE_FEE_PERCENTAGE        107
# 4                EUR  PURCHASE_FEE_PERCENTAGE        107
# ...

# %%
#Check the data types
df1.info()
df1.dtypes # Data Types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 3 to 658
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              656 non-null    object
#  1   capture_date      656 non-null    object
#  2   capture_id        656 non-null    object
#  3   amount            656 non-null    object
#  4   posting_currency  656 non-null    object
#  5   detailed_type     656 non-null    object
#  6   event_code        656 non-null    object
# dtypes: object(7)
# memory usage: 41.0+ KB
# 2
# type                object
# capture_date        object
# capture_id          object
# amount              object
# posting_currency    object
# detailed_type       object
# event_code          object
# dtype: object

# %%
df1["amount"] = pd.to_numeric(df["amount"])
df1.dtypes # Data Types
# Out:
# <ipython-input-213-35ecefc137fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["amount"] = pd.to_numeric(df["amount"])
# 2
# type                 object
# capture_date         object
# capture_id           object
# amount              float64
# posting_currency     object
# detailed_type        object
# event_code           object
# dtype: object

# %%
df1
# Out:
# 2    type                   capture_date    capture_id  amount  \
# 3     NaN  2020-01-01T12:26:46.000+00:00  11db360b111e    4.03
# 4     NaN  2021-01-02T05:48:03.000+00:00  a6691dd99235       2
# 5     NaN  2021-01-02T09:28:01.000+00:00  6c8be4e67217    4.45
# 6     NaN  2021-01-02T12:40:34.000+00:00  4f36b8da4ad8    2.38
# 7     NaN  2021-01-02T12:43:57.000+00:00  0b1e5ccfaf9f    5.68
# ..    ...                            ...           ...     ...
# 654   NaN  2021-01-10T05:39:32.000+00:00  a10d0e37d7c6   311.9
# 655   NaN  2021-01-10T05:51:02.000+00:00  2c38a7a841d4     149
# 656   NaN  2021-01-10T16:54:59.000+00:00  73b553bd2540     179
# 657   NaN  2021-01-10T18:16:28.000+00:00  68ee6ab91243  131.95
# 658   NaN  2021-01-10T20:06:55.000+00:00  4608df0e7df1   127.9
#
# 2   posting_currency            detailed_type event_code
# 3                EUR  PURCHASE_FEE_PERCENTAGE        107
# 4                EUR  PURCHASE_FEE_PERCENTAGE        107
# ...

# %%
#Check the missing values inside the rows
df1[df1.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [type, capture_date, capture_id, amount, posting_currency, detailed_type, event_code]
# Index: []

# %%
#Re-create the index
list(df1.columns).index('capture_date')
# Out:
# 1

# %%
df1.set_index('capture_date',inplace=True)
df1.head(5)
# Out:
# 2                             type    capture_id  amount posting_currency  \
# capture_date
# 2020-01-01T12:26:46.000+00:00  FEE  11db360b111e    4.03              EUR
# 2021-01-02T05:48:03.000+00:00  FEE  a6691dd99235    2.00              EUR
# 2021-01-02T09:28:01.000+00:00  FEE  6c8be4e67217    4.45              EUR
# 2021-01-02T12:40:34.000+00:00  FEE  4f36b8da4ad8    2.38              EUR
# 2021-01-02T12:43:57.000+00:00  FEE  0b1e5ccfaf9f    5.68              EUR
#
# 2                                        detailed_type event_code
# capture_date
# 2020-01-01T12:26:46.000+00:00  PURCHASE_FEE_PERCENTAGE        107
# 2021-01-02T05:48:03.000+00:00  PURCHASE_FEE_PERCENTAGE        107
# 2021-01-02T09:28:01.000+00:00  PURCHASE_FEE_PERCENTAGE        107
# 2021-01-02T12:40:34.000+00:00  PURCHASE_FEE_PERCENTAGE        107
# 2021-01-02T12:43:57.000+00:00  PURCHASE_FEE_PERCENTAGE        107

# %%
#Change the Date indexing format
df1.index = pd.to_datetime(df1.index, format = '%Y-%m-%d')

# %%
#Data visualize from type column
df1["type"].value_counts().plot.bar()
plt.show()

# %%
#Let’s create a line plot of the daily amount transaction 
df1['amount'].plot(linewidth=0.5);

# %%
# Histogram  to understand the inside data types transaction
df1['detailed_type'].hist()

# %%
# Number of event occurred
df1['event_code'].hist()

# %%
# Inside transaction
df1 = pd.DataFrame(df1, columns= ["type"])
_ = df1.groupby('type').size().plot(kind='pie',autopct='%1.1f%%', legend=True)
